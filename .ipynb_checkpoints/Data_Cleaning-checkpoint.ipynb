# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pickle

# %%
def clean_data(df):
    years = [str(year) for year in range(1960,2000)]
    years.extend(['Unnamed: 63','Indicator Code','Indicator Name'])
    df.head()
    df = df.drop(columns=years)
    df = df.drop(index = df[df.sum(axis=1) == 0].index)
    df['Average %'] = df.mean(axis=1)
    cols = df.columns.tolist()
    cols = cols[0:2] + cols[-1:] + cols[2:-1]
    df = df[cols]
    return df

def create_data(file_loc):
    df = pd.read_csv(file_loc)
    df = clean_data(df)
    return df

# %%
PrimaryCompletion = pd.read_csv('Data/Primary_Completion_Rate.csv')

# %%
PrimaryCompletion = clean_data(PrimaryCompletion)

# %%
PrimaryCompletion.shape
# Out:
# (228, 22)

# %%
ChildEmploymentF = pd.read_csv('Data/Child_Employment_Female.csv')
ChildEmploymentF = clean_data(ChildEmploymentF)
ChildEmploymentF.shape
# Out:
# (97, 22)

# %%
ChildEmploymentM = pd.read_csv('Data/Child_Employment_Male.csv')
ChildEmploymentM = clean_data(ChildEmploymentM)
ChildEmploymentM.shape
# Out:
# (97, 22)

# %%
GovExpend = create_data('Data/Government_Expenditure.csv')
GovExpend.shape
# Out:
# (209, 22)

# %%
PopDense = create_data('Data/Population_Density.csv')
PopDense.shape
# Out:
# (261, 22)

# %%
UrbanPop = create_data('Data/Urban_Population.csv')
UrbanPop.shape
# Out:
# (261, 22)

# %%
common1 = PrimaryCompletion[PrimaryCompletion.index.isin(ChildEmploymentM.index)]
common2 = ChildEmploymentM[ChildEmploymentM.index.isin(PrimaryCompletion.index)]
common3 = pd.merge(left=common1,right=common2,how='inner',left_on='Country Name',right_on='Country Name')
common3.head()
# Out:
#   Country Name Country Code_x  Average %_x     2000_x     2001_x      2002_x  \
# 0       Angola            AGO    41.000475        NaN        NaN         NaN
# 1      Albania            ALB    97.193730  97.073212  96.880661         NaN
# 2    Argentina            ARG   101.405976  98.493736  98.086487  102.030724
# 3      Armenia            ARM    95.185489        NaN        NaN   93.707390
# 4   Azerbaijan            AZE    95.473141  89.513512  95.168579   97.586014
#
#       2003_x      2004_x     2005_x     2006_x  ...  2009_y  2010_y  2011_y  \
# 0        NaN         NaN        NaN        NaN  ...     NaN     NaN     NaN
# 1  94.902428   93.870880        NaN        NaN  ...     NaN     6.4     NaN
# 2  99.923820   98.562859  96.684792  99.133202  ...     NaN     NaN     NaN
# 3  89.272758  100.047470  92.691582  93.811211  ...     NaN    12.0     NaN
# 4  92.696152   95.595428  93.430618  91.605431  ...     NaN     NaN     NaN
#
#      2012_y  2013_y  2014_y  2015_y  2016_y  2017_y  2018_y
# 0       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2  6.394649     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 43 columns]

# %%
plt.scatter(common1['Average %'],common2['Average %'])
plt.xlabel('Primary Completion %')
plt.ylabel('Child Employment % (Male)')
# Out:
# Text(0, 0.5, 'Child Employment % (Male)')

# %%
sns.lmplot(x='Average %_x',y='Average %_y',data=common3,fit_reg=True)

# %%
def plot_2(df1,df2):
    common = pd.merge(left=df1,right=df2,how='inner',left_on='Country Name',right_on='Country Name')
    print(len(common),'Observations')
    return sns.jointplot(x='Average %_x',y='Average %_y',data=common,kind='reg')

# %%
plot_2(PrimaryCompletion,ChildEmploymentF).set_axis_labels(xlabel='Primary School Enrollment %',ylabel='Female Child Employment %')
# Out:
# 92 Observations

# %%
plot_2(PrimaryCompletion,ChildEmploymentM).set_axis_labels(xlabel='Primary School Enrollment %',ylabel='Male Child Employment %')
# Out:
# 92 Observations

# %%
plot_2(PrimaryCompletion,GovExpend).set_axis_labels(xlabel='Primary School Enrollment %',ylabel='Percentage of GDP Spent on Education')
# Out:
# 194 Observations

# %%
plot_2(PrimaryCompletion,PopDense[PopDense['Average %'] < 1000]).set_axis_labels(xlabel='Primary School Enrollment %',ylabel='Population per Sq. Km')
# Out:
# 218 Observations

# %%
plot_2(PrimaryCompletion,UrbanPop).set_axis_labels(xlabel='Primary School Enrollment %',ylabel='Urban Population %')
# Out:
# 228 Observations

# %%
dataframes = [PrimaryCompletion,ChildEmploymentF,ChildEmploymentM,GovExpend,PopDense,UrbanPop]

# %%
# PrimaryCompletion.rename(columns={'Average %':'Average Primary School Completion'},inplace=True)
# ChildEmploymentF.rename(columns={'Average %':'Average Female Children Employment'},inplace=True)
# ChildEmploymentM.rename(columns={'Average %':'Average Male Children Employment'},inplace=True)
# GovExpend.rename(columns={'Average %':'Average GDP Spent on Education'},inplace=True)
# PopDense.rename(columns={'Average %':'Average Population'},inplace=True)
# UrbanPop.rename(columns={'Average %':'Average Urban Population'},inplace=True)

# %%
maindf = pd.merge(left=PrimaryCompletion[['Country Name','Average Primary School Completion']],right=ChildEmploymentF[['Country Name','Average Female Children Employment']],how='outer',left_on='Country Name',right_on='Country Name')

# %%
maindf = pd.merge(left=maindf,right=ChildEmploymentM[['Country Name','Average Male Children Employment']],how='outer',left_on='Country Name',right_on='Country Name')

# %%
maindf = pd.merge(left=maindf,right=GovExpend[['Country Name','Average GDP Spent on Education']],how='outer',left_on='Country Name',right_on='Country Name')

# %%
maindf = pd.merge(left=maindf,right=PopDense[['Country Name','Average Population']],how='outer',left_on='Country Name',right_on='Country Name')

# %%
maindf = pd.merge(left=maindf,right=UrbanPop[['Country Name','Average Urban Population']],how='outer',left_on='Country Name',right_on='Country Name')

# %%
pickle.dump(maindf,open('cleaned_data.pickle','wb'),pickle.HIGHEST_PROTOCOL)

# %%
pickle.load(open('cleaned_data.pickle','rb'))
# Out:
#                        Country Name  Average Primary School Completion  \
# 0                             Aruba                          94.458710
# 1                            Angola                          41.000475
# 2                           Albania                          97.193730
# 3                        Arab World                          82.402230
# 4              United Arab Emirates                          91.408940
# 5                         Argentina                         101.405976
# 6                           Armenia                          95.185489
# 7               Antigua and Barbuda                          88.527339
# 8                           Austria                          98.512104
# 9                        Azerbaijan                          95.473141
# 10                          Burundi                          48.716837
# 11                            Benin                          62.947807
# 12                     Burkina Faso                          43.312480
# 13                       Bangladesh                          73.783364
# 14                         Bulgaria                         100.128750
# 15                          Bahrain                          97.894147
# 16                     Bahamas, The                         101.238259
# 17                          Belarus                         102.686246
# 18                           Belize                         100.908852
# 19                          Bermuda                          92.650968
# 20                          Bolivia                          94.225282
# 21                           Brazil                         109.120073
# 22                         Barbados                          97.867450
# 23                Brunei Darussalam                         109.016022
# 24                           Bhutan                          78.989422
# 25                         Botswana                          97.604944
# 26         Central African Republic                          35.062418
# 27                           Canada                          97.303520
# 28   Central Europe and the Baltics                          96.707470
# 29                      Switzerland                          96.209762
# ..                              ...                                ...
# 233                         Andorra                                NaN
# 234                       Australia                                NaN
# 235                         Belgium                                NaN
# 236                         Curacao                                NaN
# 237                  Cayman Islands                                NaN
# 238                         Ireland                                NaN
# 239             St. Kitts and Nevis                                NaN
# 240                          Monaco                                NaN
# 241                   North America                                NaN
# 242                     Netherlands                                NaN
# 243                     New Zealand                                NaN
# 244        Turks and Caicos Islands                                NaN
# 245                   United States                                NaN
# 246                  American Samoa                                NaN
# 247                 Channel Islands                                NaN
# 248                   Faroe Islands                                NaN
# 249           Micronesia, Fed. Sts.                                NaN
# 250                       Gibraltar                                NaN
# 251                       Greenland                                NaN
# 252                            Guam                                NaN
# 253                     Isle of Man                                NaN
# 254                           Libya                                NaN
# 255        St. Martin (French part)                                NaN
# 256        Northern Mariana Islands                                NaN
# 257                   New Caledonia                                NaN
# 258                French Polynesia                                NaN
# 259       Sint Maarten (Dutch part)                                NaN
# 260                    Turkmenistan                                NaN
# 261           Virgin Islands (U.S.)                                NaN
# 262                          Kosovo                                NaN
#
#      Average Female Children Employment  Average Male Children Employment  \
# 0                                   NaN                               NaN
# 1                             30.100000                         30.000000
# 2                             18.414440                         24.173033
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# 5                              6.643352                         11.047324
# 6                              7.500000                         12.000000
# 7                                   NaN                               NaN
# 8                                   NaN                               NaN
# 9                              5.915139                          8.907135
# 10                            26.359093                         27.393380
# 11                            49.900000                         48.600000
# 12                            43.433333                         51.200000
# 13                             8.179156                         17.444095
# 14                                  NaN                               NaN
# 15                                  NaN                               NaN
# 16                                  NaN                               NaN
# 17                             6.900000                          7.050000
# 18                                  NaN                               NaN
# 19                                  NaN                               NaN
# 20                            20.868698                         22.963528
# 21                             2.975917                          6.168269
# 22                                  NaN                               NaN
# 23                                  NaN                               NaN
# 24                                  NaN                               NaN
# 25                                  NaN                               NaN
# 26                            52.750000                         51.550000
# 27                                  NaN                               NaN
# 28                                  NaN                               NaN
# 29                                  NaN                               NaN
# ..                                  ...                               ...
# 233                                 NaN                               NaN
# 234                                 NaN                               NaN
# 235                                 NaN                               NaN
# 236                                 NaN                               NaN
# 237                                 NaN                               NaN
# 238                                 NaN                               NaN
# 239                                 NaN                               NaN
# 240                                 NaN                               NaN
# 241                                 NaN                               NaN
# 242                                 NaN                               NaN
# 243                                 NaN                               NaN
# 244                                 NaN                               NaN
# 245                                 NaN                               NaN
# 246                                 NaN                               NaN
# 247                                 NaN                               NaN
# 248                                 NaN                               NaN
# 249                                 NaN                               NaN
# 250                                 NaN                               NaN
# 251                                 NaN                               NaN
# 252                                 NaN                               NaN
# 253                                 NaN                               NaN
# 254                                 NaN                               NaN
# 255                                 NaN                               NaN
# 256                                 NaN                               NaN
# 257                                 NaN                               NaN
# 258                                 NaN                               NaN
# 259                                 NaN                               NaN
# 260                                 NaN                               NaN
# 261                                 NaN                               NaN
# 262                                 NaN                               NaN
#
#      Average GDP Spent on Education  Average Population  \
# 0                         14.307146          559.365205
# 1                               NaN           18.382628
# 2                         29.845680          107.789280
# 3                               NaN           30.996646
# 4                               NaN           97.491177
# 5                         13.124827           14.823043
# 6                         10.983123          103.612610
# 7                          8.693380          196.539474
# 8                         22.971336          101.440646
# 9                               NaN          108.079907
# 10                        12.436066          331.864000
# 11                        10.900368           80.092427
# 12                        20.933738           56.071821
# 13                         8.214522         1118.070012
# 14                        19.152735           68.760986
# 15                        10.655810         1475.453198
# 16                              NaN           34.504233
# 17                              NaN           47.343018
# 18                        15.363510           13.808053
# 19                         9.789196         1190.107191
# 20                        18.167741            9.126317
# 21                        16.707305           23.122335
# 22                        19.056746          651.473195
# 23                         6.973510           72.805663
# 24                         9.354725           17.629680
# 25                        13.987890            3.420851
# 26                         5.486063            6.794024
# 27                        17.615910            3.705487
# 28                        19.527366           95.058247
# 29                        22.785541          197.017264
# ..                              ...                 ...
# 233                       12.379501          166.069429
# 234                       18.647400            2.838503
# 235                       22.304513          357.433613
# 236                       10.079560          326.956832
# 237                       12.833675          226.688377
# 238                       15.126965           63.921146
# 239                        5.900570          186.525304
# 240                        3.750886        17589.750000
# 241                       20.331323           18.605885
# 242                       16.985340          491.079233
# 243                       18.756707           16.384330
# 244                       11.785074           32.426316
# 245                       20.520173           33.402137
# 246                             NaN          286.167368
# 247                             NaN          798.312365
# 248                             NaN           34.208564
# 249                             NaN          152.258722
# 250                             NaN         3319.578947
# 251                             NaN            0.137670
# 252                             NaN          295.739864
# 253                             NaN          143.968975
# 254                             NaN            3.442854
# 255                             NaN          641.144812
# 256                             NaN          121.698284
# 257                             NaN           13.561557
# 258                             NaN           71.926589
# 259                             NaN         1013.254902
# 260                             NaN           10.822006
# 261                             NaN          309.003910
# 262                             NaN          161.485202
#
#      Average Urban Population
# 0                   44.136947
# 1                   58.639895
# 2                   51.027526
# 3                   55.952922
# 4                   83.603789
# 5                   90.614737
# 6                   63.624895
# 7                   27.498158
# 8                   58.318316
# 9                   53.322947
# 10                  10.473632
# 11                  42.633211
# 12                  23.869526
# 13                  29.846474
# 14                  71.945000
# 15                  88.672105
# 16                  82.431211
# 17                  74.264895
# 18                  45.355789
# 19                 100.000000
# 20                  65.854474
# 21                  83.991947
# 22                  32.212789
# 23                  74.545842
# 24                  33.756158
# 25                  61.012632
# 26                  39.005263
# 27                  80.639000
# 28                  61.909726
# 29                  73.577000
# ..                        ...
# 233                 89.543421
# 234                 85.046211
# 235                 97.589158
# 236                 90.042474
# 237                100.000000
# 238                 61.266684
# 239                 31.558842
# 240                100.000000
# 241                 80.628205
# 242                 85.470579
# 243                 86.264895
# 244                 89.449947
# 245                 80.623368
# 246                 87.756526
# 247                 30.847316
# 248                 40.238263
# 249                 22.379526
# 250                100.000000
# 251                 84.175632
# 252                 93.988211
# 253                 52.047789
# 254                 77.988368
# 255                       NaN
# 256                 90.876526
# 257                 66.310368
# 258                 59.305421
# 259                100.000000
# 260                 48.396632
# 261                 94.320789
# 262                       NaN
#
# [263 rows x 7 columns]

# %%
maindf.count()
# Out:
# Country Name                          263
# Average Primary School Completion     228
# Average Female Children Employment     97
# Average Male Children Employment       97
# Average GDP Spent on Education        209
# Average Population                    261
# Average Urban Population              261
# dtype: int64

# %%
maindf[maindf['Country Name'] == 'United States']
# Out:
#       Country Name  Average Primary School Completion  \
# 245  United States                                NaN
#
#      Average Female Children Employment  Average Male Children Employment  \
# 245                                 NaN                               NaN
#
#      Average GDP Spent on Education  Average Population  \
# 245                       20.520173           33.402137
#
#      Average Urban Population
# 245                 80.623368

# %%
sns.jointplot(x='Average Primary School Completion',y='Average Female Children Employment',data=maindf,kind='reg')

# %%
corr = maindf.corr()

# %%
def CorrMtx(df, dropDuplicates = True):

    # Your dataset is already a correlation matrix.
    # If you have a dateset where you need to include the calculation
    # of a correlation matrix, just uncomment the line below:
    # df = df.corr()

    # Exclude duplicate correlations by masking uper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)

    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)


CorrMtx(corr, dropDuplicates = True)
